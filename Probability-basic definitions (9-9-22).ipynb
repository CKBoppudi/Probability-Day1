# %%
import numpy as np
import pandas as pd

# %%
data_sachin = pd.read_csv(r"C:\Users\DELL\Desktop\Scaler common core maths\Sachin_ODI.csv")

# %%
data_sachin
# Out:
#      runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp  \
# 0      13       0   30   15      3      0   86.66     1   New Zealand
# 1      37       0   75   51      3      1   72.54     2  South Africa
# 2      47       0   65   40      7      0  117.50     2     Australia
# 3      48       0   37   30      9      1  160.00     2    Bangladesh
# 4       4       0   13    9      1      0   44.44     2      Pakistan
# ..    ...     ...  ...  ...    ...    ...     ...   ...           ...
# 355    14       0   34   15      2      0   93.33     2     Australia
# 356    39       0   45   30      5      0  130.00     2     Sri Lanka
# 357     6       0   25   19      1      0   31.57     1     Sri Lanka
# 358   114       0  205  147     12      1   77.55     1    Bangladesh
# 359    52       0   93   48      5      1  108.33     2      Pakistan
#
#        Ground        Date        Winner Century  Won
# 0      Napier  1995-02-16   New Zealand      No   No
# ...

# %%
data_sachin.shape
# Out:
# (360, 14)

# %% [markdown]
# # 1. Probability of win:  p[w]

# %%
data_sachin.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner Century  Won
# 0  1995-02-16   New Zealand      No   No
# 1  1995-02-18  South Africa      No   No
# 2  1995-02-22         India      No  Yes
# 3  1995-04-05         India      No  Yes
# 4  1995-04-07      Pakistan      No   No

# %%
data_sachin["Won"].value_counts()
# Out:
# Yes    184
# No     176
# Name: Won, dtype: int64

# %% [markdown]
# # So from the above we can clearly fing the probability as 51.1 %.

# %%
184/(184+176)
# Out:
# 0.5111111111111111

# %% [markdown]
# # Note - But this is not the right way to do as it is lengthy. Let us see how we can do it with help of pandas.

# %%
data_sachin.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner Century  Won
# 0  1995-02-16   New Zealand      No   No
# 1  1995-02-18  South Africa      No   No
# 2  1995-02-22         India      No  Yes
# 3  1995-04-05         India      No  Yes
# 4  1995-04-07      Pakistan      No   No

# %%
data_won = data_sachin[data_sachin["Won"] == "Yes"]

# %%
data_won
# Out:
#      runs  NotOut mins   bf  fours  sixes      sr  Inns          Opp  \
# 2      47       0   65   40      7      0  117.50     2    Australia
# 3      48       0   37   30      9      1  160.00     2   Bangladesh
# 5     112       1  137  107     15      1  104.67     2    Sri Lanka
# 6      41       0   51   41      5      0  100.00     2    Sri Lanka
# 8      39       0   79   51      4      0   76.47     2  New Zealand
# ..    ...     ...  ...  ...    ...    ...     ...   ...          ...
# 349    18       0   21   14      2      0  128.57     2    Sri Lanka
# 351    48       0   87   63      5      0   76.19     2    Sri Lanka
# 356    39       0   45   30      5      0  130.00     2    Sri Lanka
# 357     6       0   25   19      1      0   31.57     1    Sri Lanka
# 359    52       0   93   48      5      1  108.33     2     Pakistan
#
#        Ground        Date Winner Century  Won
# 2     Dunedin  1995-02-22  India      No  Yes
# ...

# %%
len(data_won)
# Out:
# 184

# %%
len(data_sachin)
# Out:
# 360

# %% [markdown]
# # Now computing the Probability as follows.

# %%
len(data_won)/len(data_sachin)
# Out:
# 0.5111111111111111

# %% [markdown]
# # 2. Probability of scoring a century. p[c]

# %%
data_sachin.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner Century  Won
# 0  1995-02-16   New Zealand      No   No
# 1  1995-02-18  South Africa      No   No
# 2  1995-02-22         India      No  Yes
# 3  1995-04-05         India      No  Yes
# 4  1995-04-07      Pakistan      No   No

# %%
data_sachin["Century"].value_counts()
# Out:
# No     314
# Yes     46
# Name: Century, dtype: int64

# %%
data_century = data_sachin[data_sachin["Century"] == "Yes"]
data_century
# Out:
#      runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp  \
# 5     112       1  137  107     15      1  104.67     2     Sri Lanka
# 12    127       1  175  138     15      1   92.02     2         Kenya
# 15    137       0  198  137      8      5  100.00     1     Sri Lanka
# 20    100       0    -  111      9      1   90.09     1      Pakistan
# 23    118       0    -  140      8      2   84.28     1      Pakistan
# 27    110       0    -  138      5      1   79.71     1     Sri Lanka
# 41    114       0  157  126     14      0   90.47     1  South Africa
# 47    104       0  121   97      8      1  107.21     2      Zimbabwe
# 55    117       0  188  137     13      2   85.40     2   New Zealand
# 85    100       0  132   89      5      7  112.35     2     Australia
# 91    143       0  187  131      9      5  109.16     2     Australia
# 92    134       0  195  131     12      3  102.29     2     Australia
# ...

# %%
data_sachin[data_sachin["Century"] == "Yes"].shape
# Out:
# (46, 14)

# %%
len(data_century)
# Out:
# 46

# %%
len(data_sachin)
# Out:
# 360

# %%
data_century_probability = len(data_century)/len(data_sachin)

# %%
data_century_probability
# Out:
# 0.12777777777777777

# %% [markdown]
# # 3. Probability of winning and century.: p[w^c]

# %%
data_sachin.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner Century  Won
# 0  1995-02-16   New Zealand      No   No
# 1  1995-02-18  South Africa      No   No
# 2  1995-02-22         India      No  Yes
# 3  1995-04-05         India      No  Yes
# 4  1995-04-07      Pakistan      No   No

# %%
data_sachin[["Century" , "Won"]].value_counts()
# Out:
# Century  Won
# No       No     160
#          Yes    154
# Yes      Yes     30
#          No      16
# dtype: int64

# %% [markdown]
# # Now making the above insight more redable. "crossstab" is being used.

# %%
pd.crosstab(index = data_sachin["Century"] , columns = data_sachin["Won"])
# Out:
# Won       No  Yes
# Century
# No       160  154
# Yes       16   30

# %%
pd.crosstab(index = data_sachin["Century"] , columns = data_sachin["Won"] , margins = True)
# Out:
# Won       No  Yes  All
# Century
# No       160  154  314
# Yes       16   30   46
# All      176  184  360

# %% [markdown]
# # Using the Pandas.

# %%
data_cetury_won = data_sachin.head(2)

# %%
data_century_won = data_sachin[(data_sachin["Century"] == "Yes") & (data_sachin["Won"] == "Yes")]

# %%
data_century_won
# Out:
#      runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp  \
# 5     112       1  137  107     15      1  104.67     2     Sri Lanka
# 12    127       1  175  138     15      1   92.02     2         Kenya
# 23    118       0    -  140      8      2   84.28     1      Pakistan
# 41    114       0  157  126     14      0   90.47     1  South Africa
# 47    104       0  121   97      8      1  107.21     2      Zimbabwe
# 55    117       0  188  137     13      2   85.40     2   New Zealand
# 85    100       0  132   89      5      7  112.35     2     Australia
# 92    134       0  195  131     12      3  102.29     2     Australia
# 95    100       1  156  103     13      0   97.08     2         Kenya
# 99    128       0  182  131      8      2   97.70     1     Sri Lanka
# 101   127       1  155  130     13      1   97.69     2      Zimbabwe
# 104   141       0  191  128     13      3  110.15     1     Australia
# ...

# %%
len(data_century_won)
# Out:
# 30

# %%
prob_century_won = len(data_century_won) / len(data_sachin)

# %%
prob_century_won
# Out:
# 0.08333333333333333

# %% [markdown]
# # Probability of "Not scoring century" and "losing".

# %%
data_sachin.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner Century  Won
# 0  1995-02-16   New Zealand      No   No
# 1  1995-02-18  South Africa      No   No
# 2  1995-02-22         India      No  Yes
# 3  1995-04-05         India      No  Yes
# 4  1995-04-07      Pakistan      No   No

# %%
century_no_loss = data_sachin[(data_sachin["Century"] == "No") & (data_sachin["Won"] == "No")]

# %%
century_no_loss
# Out:
#      runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp  \
# 0      13       0   30  15      3      0   86.66     1   New Zealand
# 1      37       0   75  51      3      1   72.54     2  South Africa
# 4       4       0   13   9      1      0   44.44     2      Pakistan
# 7      30       0   30  20      5      0  150.00     1   New Zealand
# 10     65       0   96  59      9      1  110.16     2   New Zealand
# ..    ...     ...  ...  ..    ...    ...     ...   ...           ...
# 350     2       0    9   6      0      0   33.33     2     Australia
# 352    15       0   25  24      2      0   62.50     2     Sri Lanka
# 353     3       0   21  12      0      0   25.00     2     Australia
# 354    22       0   33  23      3      0   95.65     2     Sri Lanka
# 355    14       0   34  15      2      0   93.33     2     Australia
#
#          Ground        Date        Winner Century Won
# 0        Napier  1995-02-16   New Zealand      No  No
# ...

# %%
len(century_no_loss)
# Out:
# 160

# %%
len(data_sachin)
# Out:
# 360

# %%
prob_nocen_loss = len(century_no_loss) / len(data_sachin)

# %%
prob_nocen_loss
# Out:
# 0.4444444444444444

# %% [markdown]
# # Probability of "Not scoring century" and "losing".

# %%
data_sachin.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner Century  Won
# 0  1995-02-16   New Zealand      No   No
# 1  1995-02-18  South Africa      No   No
# 2  1995-02-22         India      No  Yes
# 3  1995-04-05         India      No  Yes
# 4  1995-04-07      Pakistan      No   No

# %%
century_noor_loss = data_sachin[(data_sachin["Century"] == "No") | (data_sachin["Won"] == "No")]

# %%
century_noor_loss
# Out:
#      runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp  \
# 0      13       0   30   15      3      0   86.66     1   New Zealand
# 1      37       0   75   51      3      1   72.54     2  South Africa
# 2      47       0   65   40      7      0  117.50     2     Australia
# 3      48       0   37   30      9      1  160.00     2    Bangladesh
# 4       4       0   13    9      1      0   44.44     2      Pakistan
# ..    ...     ...  ...  ...    ...    ...     ...   ...           ...
# 355    14       0   34   15      2      0   93.33     2     Australia
# 356    39       0   45   30      5      0  130.00     2     Sri Lanka
# 357     6       0   25   19      1      0   31.57     1     Sri Lanka
# 358   114       0  205  147     12      1   77.55     1    Bangladesh
# 359    52       0   93   48      5      1  108.33     2      Pakistan
#
#        Ground        Date        Winner Century  Won
# 0      Napier  1995-02-16   New Zealand      No   No
# ...

# %%
len(century_noor_loss)
# Out:
# 330

# %%
len(data_sachin)
# Out:
# 360

# %%
prob_noor_loss = len(century_noor_loss) / len(data_sachin)

# %%
prob_noor_loss
# Out:
# 0.9166666666666666
